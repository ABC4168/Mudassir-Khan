# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("/content/avocado.csv")
df
# Out:
#        Unnamed: 0        Date  ...  year            region
# 0               0  2015-12-27  ...  2015            Albany
# 1               1  2015-12-20  ...  2015            Albany
# 2               2  2015-12-13  ...  2015            Albany
# 3               3  2015-12-06  ...  2015            Albany
# 4               4  2015-11-29  ...  2015            Albany
# ...           ...         ...  ...   ...               ...
# 18244           7  2018-02-04  ...  2018  WestTexNewMexico
# 18245           8  2018-01-28  ...  2018  WestTexNewMexico
# 18246           9  2018-01-21  ...  2018  WestTexNewMexico
# 18247          10  2018-01-14  ...  2018  WestTexNewMexico
# 18248          11  2018-01-07  ...  2018  WestTexNewMexico
#
# [18249 rows x 14 columns]

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  ...          type  year  region
# 0           0  2015-12-27          1.33  ...  conventional  2015  Albany
# 1           1  2015-12-20          1.35  ...  conventional  2015  Albany
# 2           2  2015-12-13          0.93  ...  conventional  2015  Albany
# 3           3  2015-12-06          1.08  ...  conventional  2015  Albany
# 4           4  2015-11-29          1.28  ...  conventional  2015  Albany
#
# [5 rows x 14 columns]

# %%
df.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  ...     type  year            region
# 18244           7  2018-02-04          1.63  ...  organic  2018  WestTexNewMexico
# 18245           8  2018-01-28          1.71  ...  organic  2018  WestTexNewMexico
# 18246           9  2018-01-21          1.87  ...  organic  2018  WestTexNewMexico
# 18247          10  2018-01-14          1.93  ...  organic  2018  WestTexNewMexico
# 18248          11  2018-01-07          1.62  ...  organic  2018  WestTexNewMexico
#
# [5 rows x 14 columns]

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %% [markdown]
# # Summary Statistics.

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  ...    XLarge Bags          year
# count  18249.000000  18249.000000  ...   18249.000000  18249.000000
# mean      24.232232      1.405978  ...    3106.426507   2016.147899
# std       15.481045      0.402677  ...   17692.894652      0.939938
# min        0.000000      0.440000  ...       0.000000   2015.000000
# 25%       10.000000      1.100000  ...       0.000000   2015.000000
# 50%       24.000000      1.370000  ...       0.000000   2016.000000
# 75%       38.000000      1.660000  ...     132.500000   2017.000000
# max       52.000000      3.250000  ...  551693.650000   2018.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# 1.The mean is more than median for all columns excep total bags.
# 2.There is large difference between 75 % and max of XLarge Bags Column.

# %% [markdown]
# ## **Exploring Target Variable.**

# %%
df['AveragePrice'].value_counts()
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.05      1
# 3.03      1
# 2.91      1
# 0.48      1
# 2.96      1
# Name: AveragePrice, Length: 259, dtype: int64

# %% [markdown]
# As target variable has continuous values, so , this is a regression problem.

# %% [markdown]
# ## **Data Visualizations.**

# %% [markdown]
# To check missing values.

# %%
sns.heatmap(df.isnull())

# %% [markdown]
# The data has no missing values.

# %% [markdown]
# ## **Univariate Analysis.**

# %%
sns.distplot(df['AveragePrice'])

# %% [markdown]
# The average price of single avocado is majorly in the range of 1.0-1.7

# %% [markdown]
# ## **Feature Engineering.**

# %%
df['Month'] = df['Date'].str.split("-").str[1]

# %%
df['Month'].value_counts().sort_index()
# Out:
# 01    1944
# 02    1728
# 03    1836
# 04    1404
# 05    1512
# 06    1294
# 07    1512
# 08    1404
# 09    1296
# 10    1512
# 11    1404
# 12    1403
# Name: Month, dtype: int64

# %%
df['Day'] = df['Date'].str.split("-").str[2]

# %%
df['Day'].value_counts().sort_index()
# Out:
# 01    648
# 02    432
# 03    648
# 04    756
# 05    648
# 06    539
# 07    540
# 08    648
# 09    432
# 10    648
# 11    756
# 12    648
# 13    540
# 14    540
# 15    648
# 16    432
# 17    648
# 18    755
# 19    648
# 20    540
# 21    540
# 22    648
# 23    432
# 24    648
# 25    755
# 26    648
# 27    540
# 28    540
# 29    540
# 30    432
# 31    432
# Name: Day, dtype: int64

# %% [markdown]
# ## **Bivariate Analysis.**

# %%
sns.set_style('whitegrid')
sns.stripplot(x='year',y='AveragePrice',data=df)

# %% [markdown]
# 1.The average price of single avocado is least in the year 2018.
# 2.The average price of single avocado is highest in the year 2016.
# 3.The average price of single avocado is also high in the year 2017.

# %%
sns.set_style('whitegrid')
sns.stripplot(x='Month',y='AveragePrice',data=df)

# %% [markdown]
# 1.The average price of single avocado is least in the month of February.
# 2.The average price of single avocado is highest in the month of October.
# 3.The average price of single avocado is also high in the month of March, April, August and November.

# %%
plt.figure(figsize=(18,12))
sns.set_style('whitegrid')
sns.stripplot(x='Day',y='AveragePrice',data=df)

# %% [markdown]
# 1.The average price of single avocado is least on the 31st of months.
# 2.The average price of single avocado is highest on the 30th of months.
# 3.The average price of single avocado is also high for the 27th, 16th, 12th, 6th, 2nd, 1st and 13th of months.

# %%
sns.set_style('whitegrid')
sns.stripplot(x='type',y='AveragePrice',data=df)

# %% [markdown]
# 1.The average price of single organic avocado is higher than conventional avocado.
# 2.The average price of single organic avocado is in the range of 0.5-3.8 approximately.
# 3.The average price of single conventional avocado is in the range of 0.55-2.25 approximately.

# %% [markdown]
# ## **Label Encoding.**

# %%
df_str_types=['region','type']

# %%
for value in df_str_types:
    a=(df[value].value_counts().sort_index())
    print(a)
# Out:
# Albany                 338
# Atlanta                338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# Midsouth               338
# Nashville              338
# NewOrleansMobile       338
# NewYork                338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# Sacramento             338
# SanDiego               338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# WestTexNewMexico       335
# Name: region, dtype: int64
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
for value in df_str_types:
    df[value]=LE.fit_transform(df[value])
    print(df[value].value_counts().sort_index())
# Out:
# 0     338
# 1     338
# 2     338
# 3     338
# 4     338
# 5     338
# 6     338
# 7     338
# 8     338
# 9     338
# 10    338
# 11    338
# 12    338
# 13    338
# 14    338
# 15    338
# 16    338
# 17    338
# 18    338
# 19    338
# 20    338
# 21    338
# 22    338
# 23    338
# 24    338
# 25    338
# 26    338
# 27    338
# 28    338
# 29    338
# 30    338
# 31    338
# 32    338
# 33    338
# 34    338
# 35    338
# 36    338
# 37    338
# 38    338
# 39    338
# 40    338
# 41    338
# 42    338
# 43    338
# 44    338
# 45    338
# 46    338
# 47    338
# 48    338
# 49    338
# 50    338
# 51    338
# 52    338
# 53    335
# Name: region, dtype: int64
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %% [markdown]
# ## **Bivariate Analysis.**

# %%
plt.figure(figsize=(18,12))
sns.set_style('whitegrid')
sns.stripplot(x='region',y='AveragePrice',data=df)

# %% [markdown]
# 1.SanFrancisco has the highest average price of single avocado.
# 2.SouthCentral has the lowest average price of single avocado.
# 3.Pittsburgh, Houston, DallasFtWorth and GreatLakes also have low average price of single avocado.
# 4.Tampa, RaleighGreensboro, MiamiFtLauderdale and LasVegas also have high average price of single avocado.

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume  ...  year  region  Month  Day
# 0           0  2015-12-27          1.33      64236.62  ...  2015       0     12   27
# 1           1  2015-12-20          1.35      54876.98  ...  2015       0     12   20
# 2           2  2015-12-13          0.93     118220.22  ...  2015       0     12   13
# 3           3  2015-12-06          1.08      78992.15  ...  2015       0     12   06
# 4           4  2015-11-29          1.28      51039.60  ...  2015       0     11   29
#
# [5 rows x 16 columns]

# %% [markdown]
# ## **Dropping of Columns.**

# %% [markdown]
# As the Unnamed: 0 column is only giving us the indexes , so we will drop that irrelevant column to avoid overfitting.As the year column is present in the dataset already, so we will drop the date,day and month column from dataset as per our requirement of developing the model.

# %%
df.drop(['Unnamed: 0','Date','Day','Month'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    AveragePrice  Total Volume     4046  ...  type  year  region
# 0          1.33      64236.62  1036.74  ...     0  2015       0
# 1          1.35      54876.98   674.28  ...     0  2015       0
# 2          0.93     118220.22   794.70  ...     0  2015       0
# 3          1.08      78992.15  1132.00  ...     0  2015       0
# 4          1.28      51039.60   941.48  ...     0  2015       0
#
# [5 rows x 12 columns]

# %%
df.shape
# Out:
# (18249, 12)

# %%
dfcor=df.corr()
dfcor
# Out:
#               AveragePrice  Total Volume  ...      year    region
# AveragePrice      1.000000     -0.192752  ...  0.093197 -0.011716
# Total Volume     -0.192752      1.000000  ...  0.017193  0.174176
# 4046             -0.208317      0.977863  ...  0.003353  0.192073
# 4225             -0.172928      0.974181  ... -0.009559  0.145726
# 4770             -0.179446      0.872202  ... -0.036531  0.095252
# Total Bags       -0.177088      0.963047  ...  0.071552  0.175256
# Small Bags       -0.174730      0.967238  ...  0.063915  0.164702
# Large Bags       -0.172940      0.880640  ...  0.087891  0.198768
# XLarge Bags      -0.117592      0.747157  ...  0.081033  0.082281
# type              0.615845     -0.232434  ... -0.000032 -0.000280
# year              0.093197      0.017193  ...  1.000000 -0.000055
# region           -0.011716      0.174176  ... -0.000055  1.000000
#
# [12 rows x 12 columns]

# %%
plt.figure(figsize=(10,8))
sns.heatmap(dfcor,cmap='YlOrRd_r',annot=True)

# %% [markdown]
# 1.Average price is highly positively correlated to type.
# 2.type is highly negatively correlated to Total Volume.
# 3.Total Volume is highly positively correlated to 4046.
# 4.Total Volume is highly negatively correlated to 4046.

# %%
sns.scatterplot(x='Total Volume',y='AveragePrice',data=df)

# %% [markdown]
# Total volume of avocados sold is inversely proportional to the average price of a single avocado.

# %%
sns.scatterplot(x='4046',y='AveragePrice',data=df)

# %% [markdown]
# Total number of avocados with Product Lookup codes (PLU’s) 4046 sold is also inversely proportional to the average price of a single avocado.

# %%
sns.scatterplot(x='4225',y='AveragePrice',data=df)

# %% [markdown]
# Total number of avocados with Product Lookup codes (PLU’s) 4225 sold is also inversely proportional to the average price of a single avocado.

# %%
sns.scatterplot(x='4770',y='AveragePrice',data=df)

# %% [markdown]
# Total number of avocados with Product Lookup codes (PLU’s) 4770 sold is also inversely proportional to the average price of a single avocado.

# %%
sns.scatterplot(x='Total Bags',y='AveragePrice',data=df)

# %% [markdown]
# Average price of a single avocado is also inversely proportional to total numbers of bags in which avocados are sold.

# %%
sns.scatterplot(x='Small Bags',y='AveragePrice',data=df)

# %% [markdown]
# Average price of a single avocado is also inversely proportional to total numbers of small bags in which avocados are sold.

# %%
sns.scatterplot(x='Large Bags',y='AveragePrice',data=df)

# %% [markdown]
# Average price of a single avocado is also inversely proportional to total numbers of large bags in which avocados are sold.

# %%
sns.scatterplot(x='XLarge Bags',y='AveragePrice',data=df)

# %% [markdown]
# Average price of a single avocado is also inversely proportional to total numbers Xlarge bags in which avocados are sold.

# %% [markdown]
# ## **Plotting Outliers.**

# %%
df.plot(kind='box',subplots=True,layout=(4,3),sharex=False,fontsize=1,figsize=(18,12))
# Out:
# AveragePrice        AxesSubplot(0.125,0.71587;0.227941x0.16413)
# Total Volume     AxesSubplot(0.398529,0.71587;0.227941x0.16413)
# 4046             AxesSubplot(0.672059,0.71587;0.227941x0.16413)
# 4225               AxesSubplot(0.125,0.518913;0.227941x0.16413)
# 4770            AxesSubplot(0.398529,0.518913;0.227941x0.16413)
# Total Bags      AxesSubplot(0.672059,0.518913;0.227941x0.16413)
# Small Bags         AxesSubplot(0.125,0.321957;0.227941x0.16413)
# Large Bags      AxesSubplot(0.398529,0.321957;0.227941x0.16413)
# XLarge Bags     AxesSubplot(0.672059,0.321957;0.227941x0.16413)
# type                  AxesSubplot(0.125,0.125;0.227941x0.16413)
# year               AxesSubplot(0.398529,0.125;0.227941x0.16413)
# region             AxesSubplot(0.672059,0.125;0.227941x0.16413)
# dtype: object

# %% [markdown]
# All the columns have outliers except type, year and region.

# %% [markdown]
# ## **Removing Outliers.**

# %%
df.dtypes
# Out:
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type              int64
# year              int64
# region            int64
# dtype: object

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[0.18868864, 0.22771641, 0.23081597, ..., 0.99983562, 1.22128204,
#         1.7002522 ],
#        [0.13901962, 0.23042664, 0.23110251, ..., 0.99983562, 1.22128204,
#         1.7002522 ],
#        [1.18206895, 0.21208462, 0.23100731, ..., 0.99983562, 1.22128204,
#         1.7002522 ],
#        ...,
#        [1.15237477, 0.24233073, 0.2306933 , ..., 1.00016441, 1.97050371,
#         1.70081131],
#        [1.30138182, 0.24162464, 0.2304279 , ..., 1.00016441, 1.97050371,
#         1.70081131],
#        [0.53151208, 0.24125273, 0.22934712, ..., 1.00016441, 1.97050371,
#         1.70081131]])

# %%
threshold=3
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (17651, 12)

# %%
df.shape
# Out:
# (18249, 12)

# %%
# 598 rows are removed as outliers
((18249-17651)/18249)*100
# Out:
# 3.276891884486821

# %%
df=df_new

# %%
df.shape
# Out:
# (17651, 12)

# %% [markdown]
# ## **To check skewness.**

# %%
df.plot(kind='density',subplots=True,layout=(3,4),sharex=False,fontsize=1,figsize=(18,12))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca68d3ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca69858d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4c70e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4c10810>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4c31310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4bd0cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4bf09d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4b91410>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4b912d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4bb11d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4b71210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f1ca4b8c690>]],
#       dtype=object)

# %% [markdown]
# Total Volume, 4046, 4225, 4770, Total Bags, Small Bags, Large Bags, XLarge Bags.

# %%
df.skew()
# Out:
# AveragePrice    0.377432
# Total Volume    3.767138
# 4046            4.909848
# 4225            4.455745
# 4770            5.117170
# Total Bags      4.066771
# Small Bags      4.222706
# Large Bags      5.053434
# XLarge Bags     6.135607
# type           -0.037741
# year            0.229976
# region          0.012798
# dtype: float64

# %% [markdown]
# Because the skewness of 4046, 4225, 4770, Small Bags, Large Bags and XLarge Bags is very high and therir corresponding aggregate column is also present in the dataset as columns of Total Bags and Total Volume. So, we will drop 4046, 4225, 4770, Small Bags, Large Bags and XLarge Bags from dataset.

# %% [markdown]
# ## **Dropping of Columns.**

# %%
df.drop(['4046', '4225', '4770','Small Bags', 'Large Bags', 'XLarge Bags'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['AveragePrice', 'Total Volume', 'Total Bags', 'type', 'year', 'region'], dtype='object')

# %% [markdown]
# ## **Train Test Split.**

# %%
x=df[['Total Volume', 'Total Bags', 'type', 'year', 'region']]
y=df['AveragePrice']

# %% [markdown]
# ## **Scaling.**

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)

# %%
x=pd.DataFrame(x)

# %%
x.columns=['Total Volume', 'Total Bags', 'type', 'year', 'region']

# %% [markdown]
# ## **Algorithms.**

# %%
from sklearn.model_selection import train_test_split
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=i)
    lm=LinearRegression()
    lm.fit(x_train,y_train)
    pred=lm.predict(x_test)
    r2score=r2_score(y_test,pred)
    print(r2_score(y_test,pred))
    print('error:')
    print('Mean absolute error:',mean_absolute_error(y_test,pred))
    print('Mean squared error:',mean_squared_error(y_test,pred))
    print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
    if r2score>maxAccu:
        maxAccu=r2score
        maxRS=i
        
print("Best accuracy is",maxAccu,"on Random_state",maxRS)
# Out:
# 0.3831377720833691
# error:
# Mean absolute error: 0.23664956894777064
# Mean squared error: 0.0924911954010628
# Root Mean squared error: 0.3041236514989632
# 0.39698206044512874
# error:
# Mean absolute error: 0.23634627674273628
# Mean squared error: 0.09061030465276451
# Root Mean squared error: 0.30101545583701267
# 0.4080831978056694
# error:
# Mean absolute error: 0.23348739572228064
# Mean squared error: 0.08818695074179726
# Root Mean squared error: 0.2969628777167228
# 0.39929598712945924
# error:
# Mean absolute error: 0.23180031624703282
# Mean squared error: 0.08692271679121007
# Root Mean squared error: 0.2948265876599498
# 0.3901344380636663
# error:
# Mean absolute error: 0.2371910022089885
# Mean squared error: 0.09163074689475709
# Root Mean squared error: 0.30270571004650226
# 0.4126214684446714
# error:
# Mean absolute error: 0.23234455884207697
# Mean squared error: 0.08774059521547269
# Root Mean squared error: 0.296210390120726
# 0.3974802821453547
# error:
# Mean absolute error: 0.2339342889801271
# Mean squared error: 0.08973563838442519
# Root Mean squared error: 0.2995590732800881
# 0.41318265265327847
# error:
# Mean absolute error: 0.23461120023031665
# Mean squared error: 0.09021090239310472
# Root Mean squared error: 0.3003512983043435
# 0.3919513660123035
# error:
# Mean absolute error: 0.2356503652794917
# Mean squared error: 0.0903296327014086
# Root Mean squared error: 0.3005488857098103
# 0.3724522758832296
# error:
# Mean absolute error: 0.2376268282291868
# Mean squared error: 0.09129309240134714
# Root Mean squared error: 0.3021474679711004
# 0.39898782808355204
# error:
# Mean absolute error: 0.23424155375955028
# Mean squared error: 0.09031055362280165
# Root Mean squared error: 0.3005171436420918
# 0.38529832218375193
# error:
# Mean absolute error: 0.23623351201910475
# Mean squared error: 0.09110175541004552
# Root Mean squared error: 0.30183067340819675
# 0.39122027967291684
# error:
# Mean absolute error: 0.23432402566130814
# Mean squared error: 0.08968479549585592
# Root Mean squared error: 0.29947419838085537
# 0.40670426465348963
# error:
# Mean absolute error: 0.2310412369864477
# Mean squared error: 0.08717193965547619
# Root Mean squared error: 0.29524894522330847
# 0.37993798504320275
# error:
# Mean absolute error: 0.23416052264935253
# Mean squared error: 0.08960494770884683
# Root Mean squared error: 0.29934085539539507
# 0.3876784992914296
# error:
# Mean absolute error: 0.23478478461254854
# Mean squared error: 0.08943419614291354
# Root Mean squared error: 0.2990555067924908
# 0.38683942333886023
# error:
# Mean absolute error: 0.23300398703387443
# Mean squared error: 0.08881601614791029
# Root Mean squared error: 0.2980201606400317
# 0.3929598835501572
# error:
# Mean absolute error: 0.23600073245946554
# Mean squared error: 0.09090898259076467
# Root Mean squared error: 0.3015111649520871
# 0.3979742721471681
# error:
# Mean absolute error: 0.23324718907227332
# Mean squared error: 0.08738142623463545
# Root Mean squared error: 0.29560349496349914
# 0.39298130997847547
# error:
# Mean absolute error: 0.23683631816917922
# Mean squared error: 0.09102771377486683
# Root Mean squared error: 0.30170799421769856
# 0.38238462974385456
# error:
# Mean absolute error: 0.2372831392372866
# Mean squared error: 0.09224206551733734
# Root Mean squared error: 0.303713788816605
# 0.38342563547211195
# error:
# Mean absolute error: 0.23463941031822882
# Mean squared error: 0.09060923397801403
# Root Mean squared error: 0.3010136773935929
# 0.4121095471272195
# error:
# Mean absolute error: 0.23166507753940854
# Mean squared error: 0.08742960270097055
# Root Mean squared error: 0.2956849720580513
# 0.3852430294249629
# error:
# Mean absolute error: 0.2327803853366048
# Mean squared error: 0.08937251894781979
# Root Mean squared error: 0.29895236902861266
# 0.39876288693409523
# error:
# Mean absolute error: 0.2334796156107944
# Mean squared error: 0.08934232085849836
# Root Mean squared error: 0.2989018582386171
# 0.3862410258606329
# error:
# Mean absolute error: 0.23789490679136852
# Mean squared error: 0.09400450098275324
# Root Mean squared error: 0.30660153454076716
# 0.38486786974316634
# error:
# Mean absolute error: 0.23882569065113007
# Mean squared error: 0.09191929707158812
# Root Mean squared error: 0.3031819537366763
# 0.39267391489864123
# error:
# Mean absolute error: 0.2359109562596008
# Mean squared error: 0.08906721983093088
# Root Mean squared error: 0.2984413172315973
# 0.40437568227394705
# error:
# Mean absolute error: 0.23778912574869707
# Mean squared error: 0.09125261370743078
# Root Mean squared error: 0.30208047554820683
# 0.39017193133168726
# error:
# Mean absolute error: 0.23278235364686156
# Mean squared error: 0.08802137691240794
# Root Mean squared error: 0.29668396807446124
# 0.40583608249870173
# error:
# Mean absolute error: 0.23509401985501016
# Mean squared error: 0.09007776541304593
# Root Mean squared error: 0.3001295810363349
# 0.39332613825091844
# error:
# Mean absolute error: 0.23648403755321276
# Mean squared error: 0.09012208774590193
# Root Mean squared error: 0.3002034106167049
# 0.39390372523206396
# error:
# Mean absolute error: 0.23203771876161142
# Mean squared error: 0.08787947789387782
# Root Mean squared error: 0.29644472991415755
# 0.37492445789710405
# error:
# Mean absolute error: 0.2387255898092711
# Mean squared error: 0.09383193785935515
# Root Mean squared error: 0.30631999258839626
# 0.39229113065639587
# error:
# Mean absolute error: 0.2356856407288163
# Mean squared error: 0.08920812025760799
# Root Mean squared error: 0.29867728446871883
# 0.38740707599850654
# error:
# Mean absolute error: 0.23280230284820538
# Mean squared error: 0.08789601725281412
# Root Mean squared error: 0.29647262479496167
# 0.3970693505353553
# error:
# Mean absolute error: 0.23625980715607098
# Mean squared error: 0.09077882436657268
# Root Mean squared error: 0.301295244513704
# 0.4105451099858918
# error:
# Mean absolute error: 0.22989578669166083
# Mean squared error: 0.08695810696016851
# Root Mean squared error: 0.2948866001705885
# 0.3591023210993495
# error:
# Mean absolute error: 0.23877068641168164
# Mean squared error: 0.0933066023827683
# Root Mean squared error: 0.30546129441022196
# 0.40260282512318324
# error:
# Mean absolute error: 0.23178862199163447
# Mean squared error: 0.0878968205781757
# Root Mean squared error: 0.2964739795971574
# 0.38943069891148174
# error:
# Mean absolute error: 0.23760843571979418
# Mean squared error: 0.09007742377703587
# Root Mean squared error: 0.3001290118882809
# 0.3800679034028309
# error:
# Mean absolute error: 0.23686372667069477
# Mean squared error: 0.09195289596151605
# Root Mean squared error: 0.30323735911248806
# 0.4066635422468238
# error:
# Mean absolute error: 0.23383231584248676
# Mean squared error: 0.08869002466356193
# Root Mean squared error: 0.2978087048149566
# 0.3702394625628126
# error:
# Mean absolute error: 0.24068739140754528
# Mean squared error: 0.09473288587762978
# Root Mean squared error: 0.3077870788022619
# 0.380388663629753
# error:
# Mean absolute error: 0.23816099765094265
# Mean squared error: 0.09194377870884565
# Root Mean squared error: 0.30322232554488077
# 0.40259693428776944
# error:
# Mean absolute error: 0.23441043451308186
# Mean squared error: 0.08994848536169699
# Root Mean squared error: 0.2999141299800611
# 0.3921946974807049
# error:
# Mean absolute error: 0.23498496898367013
# Mean squared error: 0.08922972626423595
# Root Mean squared error: 0.29871345176311687
# 0.39886040431659264
# error:
# Mean absolute error: 0.23442280080095246
# Mean squared error: 0.08892177810550089
# Root Mean squared error: 0.2981975487919056
# 0.39084658479782164
# error:
# Mean absolute error: 0.23418872880463987
# Mean squared error: 0.08984978231268871
# Root Mean squared error: 0.2997495326313099
# 0.3842075112499982
# error:
# Mean absolute error: 0.23496811359367342
# Mean squared error: 0.08988243380772588
# Root Mean squared error: 0.29980399231452187
# 0.381829507677361
# error:
# Mean absolute error: 0.23760280017146537
# Mean squared error: 0.09209494438245713
# Root Mean squared error: 0.3034714885824649
# 0.3937693845598448
# error:
# Mean absolute error: 0.2374437668538266
# Mean squared error: 0.09250643884174117
# Root Mean squared error: 0.3041487117213242
# 0.4025309989179513
# error:
# Mean absolute error: 0.2340186746169696
# Mean squared error: 0.08914974646838503
# Root Mean squared error: 0.29857954797404496
# 0.3685518809442694
# error:
# Mean absolute error: 0.24066539761821606
# Mean squared error: 0.09422391174438731
# Root Mean squared error: 0.3069591369293107
# 0.4036307966656536
# error:
# Mean absolute error: 0.23562864027594752
# Mean squared error: 0.09045445168600455
# Root Mean squared error: 0.30075646574264125
# 0.39627069391404746
# error:
# Mean absolute error: 0.23180844053286342
# Mean squared error: 0.0863554149695856
# Root Mean squared error: 0.29386291867056924
# 0.39701489456645933
# error:
# Mean absolute error: 0.2373080300293124
# Mean squared error: 0.09252673534747875
# Root Mean squared error: 0.304182075979961
# 0.3999637883112451
# error:
# Mean absolute error: 0.23748586665036636
# Mean squared error: 0.09046276637647978
# Root Mean squared error: 0.30077028838713404
# 0.38666227848254764
# error:
# Mean absolute error: 0.23279445207595145
# Mean squared error: 0.08874525551995215
# Root Mean squared error: 0.297901419130477
# 0.39836565835505466
# error:
# Mean absolute error: 0.23673560111311343
# Mean squared error: 0.09218383630028056
# Root Mean squared error: 0.3036179116921144
# 0.38033282829375037
# error:
# Mean absolute error: 0.23977131539566301
# Mean squared error: 0.09298715269251293
# Root Mean squared error: 0.304937948921601
# 0.37051528480830587
# error:
# Mean absolute error: 0.23749489719524963
# Mean squared error: 0.09329929031100777
# Root Mean squared error: 0.30544932527509006
# 0.3861737144311199
# error:
# Mean absolute error: 0.24116613081900243
# Mean squared error: 0.0940781529165561
# Root Mean squared error: 0.3067216212081504
# 0.4007738442228581
# error:
# Mean absolute error: 0.2330805430305199
# Mean squared error: 0.08945925839048395
# Root Mean squared error: 0.2990974061915013
# 0.37828650819788234
# error:
# Mean absolute error: 0.23592977768537238
# Mean squared error: 0.0907765815381529
# Root Mean squared error: 0.30129152251291924
# 0.37384522908767637
# error:
# Mean absolute error: 0.2344423304434348
# Mean squared error: 0.0904252707219626
# Root Mean squared error: 0.3007079492164492
# 0.39282218675334835
# error:
# Mean absolute error: 0.23447708578278256
# Mean squared error: 0.09014697017930222
# Root Mean squared error: 0.30024485037932325
# 0.38806193370625086
# error:
# Mean absolute error: 0.23575047960719087
# Mean squared error: 0.09158047647586773
# Root Mean squared error: 0.30262266351988204
# 0.4025860565621068
# error:
# Mean absolute error: 0.23862489571142237
# Mean squared error: 0.0918497010747914
# Root Mean squared error: 0.30306715604761825
# 0.3961780319269278
# error:
# Mean absolute error: 0.23901040343522528
# Mean squared error: 0.09319125905667353
# Root Mean squared error: 0.30527243415787403
# 0.38965391125912907
# error:
# Mean absolute error: 0.2392746186723989
# Mean squared error: 0.09224653161155218
# Root Mean squared error: 0.3037211411995421
# 0.391762702181201
# error:
# Mean absolute error: 0.2379647817005994
# Mean squared error: 0.09351262498442431
# Root Mean squared error: 0.30579834038860365
# 0.37630379100051936
# error:
# Mean absolute error: 0.2376370089929071
# Mean squared error: 0.09229473752140635
# Root Mean squared error: 0.3038004896661728
# 0.38847801825164074
# error:
# Mean absolute error: 0.23706836627404468
# Mean squared error: 0.09002282547767693
# Root Mean squared error: 0.3000380400510524
# 0.3945684549803652
# error:
# Mean absolute error: 0.23588070004458936
# Mean squared error: 0.09150266357679541
# Root Mean squared error: 0.3024940719696758
# 0.3983310803500695
# error:
# Mean absolute error: 0.22880974815756494
# Mean squared error: 0.08558263832761859
# Root Mean squared error: 0.29254510477466306
# 0.3906681628692148
# error:
# Mean absolute error: 0.23336590795287077
# Mean squared error: 0.08964846971129205
# Root Mean squared error: 0.2994135429657317
# 0.39165971567569
# error:
# Mean absolute error: 0.23603820724999836
# Mean squared error: 0.09238122907846662
# Root Mean squared error: 0.3039428056040587
# 0.3921832400177814
# error:
# Mean absolute error: 0.23420887326049764
# Mean squared error: 0.08908075324884375
# Root Mean squared error: 0.2984639898695381
# 0.39011169553286185
# error:
# Mean absolute error: 0.23038908428535423
# Mean squared error: 0.0860000813909282
# Root Mean squared error: 0.29325770474265156
# 0.391997390380479
# error:
# Mean absolute error: 0.23831263390320143
# Mean squared error: 0.09132107343509244
# Root Mean squared error: 0.302193768028218
# 0.40979318762599604
# error:
# Mean absolute error: 0.23204896900850025
# Mean squared error: 0.08788395492752887
# Root Mean squared error: 0.29645228102939075
# 0.37626204723441925
# error:
# Mean absolute error: 0.23770111695256593
# Mean squared error: 0.0920955252712366
# Root Mean squared error: 0.30347244565402737
# 0.41673569956049994
# error:
# Mean absolute error: 0.2275283972706915
# Mean squared error: 0.08437414772584366
# Root Mean squared error: 0.29047228392024543
# 0.3966550559653089
# error:
# Mean absolute error: 0.24355055687429578
# Mean squared error: 0.09574579972292996
# Root Mean squared error: 0.3094281818498922
# 0.3932056248191651
# error:
# Mean absolute error: 0.23877945695929662
# Mean squared error: 0.09326239855510085
# Root Mean squared error: 0.30538892998126316
# 0.38528755346935706
# error:
# Mean absolute error: 0.23771236887767883
# Mean squared error: 0.09269068758617627
# Root Mean squared error: 0.3044514535786884
# 0.3860290564631179
# error:
# Mean absolute error: 0.23649943823969377
# Mean squared error: 0.09032613079614205
# Root Mean squared error: 0.3005430598036528
# 0.4013922201933736
# error:
# Mean absolute error: 0.2336184884071131
# Mean squared error: 0.08968876984254182
# Root Mean squared error: 0.2994808338484148
# 0.37208046387709137
# error:
# Mean absolute error: 0.23826989124084463
# Mean squared error: 0.09297127986650322
# Root Mean squared error: 0.3049119214896381
# 0.3838816955729033
# error:
# Mean absolute error: 0.23750230311320916
# Mean squared error: 0.09182447516613346
# Root Mean squared error: 0.3030255355017683
# 0.3722114907189431
# error:
# Mean absolute error: 0.23672293837451663
# Mean squared error: 0.09105221911435904
# Root Mean squared error: 0.30174860250605806
# 0.3915230469048697
# error:
# Mean absolute error: 0.23648080111409345
# Mean squared error: 0.09075767316954453
# Root Mean squared error: 0.3012601420193925
# 0.3773367706289458
# error:
# Mean absolute error: 0.23650897267031512
# Mean squared error: 0.09115846088296019
# Root Mean squared error: 0.30192459469702065
# 0.4030931615412139
# error:
# Mean absolute error: 0.2363919148943018
# Mean squared error: 0.09063214181146496
# Root Mean squared error: 0.3010517261393214
# 0.39721373245891556
# error:
# Mean absolute error: 0.2374407654827402
# Mean squared error: 0.09233545036537234
# Root Mean squared error: 0.30386748816774123
# 0.3662766331234496
# error:
# Mean absolute error: 0.23967157617025614
# Mean squared error: 0.09388990716051246
# Root Mean squared error: 0.3064146001099041
# 0.38737778555707525
# error:
# Mean absolute error: 0.2335996147718728
# Mean squared error: 0.08907619467248803
# Root Mean squared error: 0.29845635304427354
# 0.40225156192311606
# error:
# Mean absolute error: 0.2271822679010969
# Mean squared error: 0.08618126161939364
# Root Mean squared error: 0.29356645179480856
# 0.39767619783210784
# error:
# Mean absolute error: 0.2316413143793394
# Mean squared error: 0.08757865105170834
# Root Mean squared error: 0.2959369038354432
# 0.40511066936517437
# error:
# Mean absolute error: 0.23163735078424103
# Mean squared error: 0.08866959801253792
# Root Mean squared error: 0.2977744079207243
# 0.3813851152362314
# error:
# Mean absolute error: 0.23901522588786786
# Mean squared error: 0.09267018035738683
# Root Mean squared error: 0.304417772735737
# 0.38624345494971934
# error:
# Mean absolute error: 0.23796588158897797
# Mean squared error: 0.09097669593302318
# Root Mean squared error: 0.30162343399182895
# 0.3936514467108403
# error:
# Mean absolute error: 0.23500345041273754
# Mean squared error: 0.09052774342013138
# Root Mean squared error: 0.3008782867209453
# 0.3844480221522565
# error:
# Mean absolute error: 0.23278987526291772
# Mean squared error: 0.08933093315837337
# Root Mean squared error: 0.29888280840217857
# 0.4133809552781652
# error:
# Mean absolute error: 0.234462075767206
# Mean squared error: 0.08995038971587871
# Root Mean squared error: 0.2999173047956365
# 0.3940260844703425
# error:
# Mean absolute error: 0.23575375292542836
# Mean squared error: 0.09088414889548675
# Root Mean squared error: 0.30146998009003606
# 0.4059519343003468
# error:
# Mean absolute error: 0.2343493868971537
# Mean squared error: 0.08901539528149734
# Root Mean squared error: 0.2983544792381997
# 0.4042119358098001
# error:
# Mean absolute error: 0.23188939586630092
# Mean squared error: 0.08758330455041867
# Root Mean squared error: 0.29594476604667075
# 0.36849779483236356
# error:
# Mean absolute error: 0.23964276435079293
# Mean squared error: 0.09334831728948204
# Root Mean squared error: 0.30552956860094904
# 0.38370570063802434
# error:
# Mean absolute error: 0.23757840816846548
# Mean squared error: 0.0927883652202547
# Root Mean squared error: 0.30461182711814505
# 0.39624979794965143
# error:
# Mean absolute error: 0.23587024290201958
# Mean squared error: 0.09190749962065607
# Root Mean squared error: 0.3031624970550547
# 0.38614796130653184
# error:
# Mean absolute error: 0.23486657000087163
# Mean squared error: 0.09017937149080633
# Root Mean squared error: 0.3002988036786133
# 0.3874078212544452
# error:
# Mean absolute error: 0.23443954045555807
# Mean squared error: 0.08982391553129117
# Root Mean squared error: 0.2997063821997976
# 0.3887261364788882
# error:
# Mean absolute error: 0.2390825978127424
# Mean squared error: 0.09370683198690759
# Root Mean squared error: 0.3061157166610489
# 0.3932068725734612
# error:
# Mean absolute error: 0.2383797305559812
# Mean squared error: 0.09270544071435143
# Root Mean squared error: 0.3044756816469115
# 0.38518874300121064
# error:
# Mean absolute error: 0.23594058148704783
# Mean squared error: 0.09108934991541794
# Root Mean squared error: 0.3018101222878682
# 0.3960891357377375
# error:
# Mean absolute error: 0.23664872169512785
# Mean squared error: 0.09186426333512365
# Root Mean squared error: 0.303091179903216
# 0.3815834105883652
# error:
# Mean absolute error: 0.23266501478491342
# Mean squared error: 0.08897801520067988
# Root Mean squared error: 0.2982918289204045
# 0.3835409749966612
# error:
# Mean absolute error: 0.2349633042039952
# Mean squared error: 0.09140179243047221
# Root Mean squared error: 0.3023272935586071
# 0.38306626176502523
# error:
# Mean absolute error: 0.235237332983999
# Mean squared error: 0.09101949579571103
# Root Mean squared error: 0.3016943748161557
# 0.3834985732397823
# error:
# Mean absolute error: 0.2315881817324908
# Mean squared error: 0.08783133377931997
# Root Mean squared error: 0.2963635162757386
# 0.38110673169397336
# error:
# Mean absolute error: 0.23663651318805778
# Mean squared error: 0.09072534380934352
# Root Mean squared error: 0.3012064803574842
# 0.3898079172192921
# error:
# Mean absolute error: 0.23363373338868804
# Mean squared error: 0.08918440537249102
# Root Mean squared error: 0.2986375819827287
# 0.38289960361305186
# error:
# Mean absolute error: 0.23521458840027637
# Mean squared error: 0.09094585082011333
# Root Mean squared error: 0.3015722978327309
# 0.40036490908262
# error:
# Mean absolute error: 0.23424449135894046
# Mean squared error: 0.09036796380608543
# Root Mean squared error: 0.3006126474486485
# 0.3812702875078249
# error:
# Mean absolute error: 0.23385102254037327
# Mean squared error: 0.08948810604053954
# Root Mean squared error: 0.29914562681165763
# 0.3842336692578844
# error:
# Mean absolute error: 0.23753487292263384
# Mean squared error: 0.0920875623180338
# Root Mean squared error: 0.3034593256402476
# 0.40294746540484505
# error:
# Mean absolute error: 0.23851070163444377
# Mean squared error: 0.09206643875061994
# Root Mean squared error: 0.30342451903335027
# 0.3957297167028845
# error:
# Mean absolute error: 0.2395289496411475
# Mean squared error: 0.09374754844709522
# Root Mean squared error: 0.3061822144525956
# 0.38854684294846076
# error:
# Mean absolute error: 0.24055033817309512
# Mean squared error: 0.09385819216531371
# Root Mean squared error: 0.3063628439698811
# 0.3857283951637762
# error:
# Mean absolute error: 0.23723920569176424
# Mean squared error: 0.09128391237244714
# Root Mean squared error: 0.3021322762838276
# 0.3796222291298813
# error:
# Mean absolute error: 0.23687592205141356
# Mean squared error: 0.09106108309432248
# Root Mean squared error: 0.30176328983877826
# 0.40020438849375817
# error:
# Mean absolute error: 0.23453404788694737
# Mean squared error: 0.08990876404926677
# Root Mean squared error: 0.29984790152553475
# 0.38078513300553685
# error:
# Mean absolute error: 0.23491045357761553
# Mean squared error: 0.08913186911756715
# Root Mean squared error: 0.29854960913986667
# 0.39400937464636665
# error:
# Mean absolute error: 0.23293746623453832
# Mean squared error: 0.08824434043394155
# Root Mean squared error: 0.2970594897220783
# 0.3974492773054292
# error:
# Mean absolute error: 0.23504572196344667
# Mean squared error: 0.08980773557248166
# Root Mean squared error: 0.2996793879673436
# 0.4032301215569183
# error:
# Mean absolute error: 0.2293637598163872
# Mean squared error: 0.08563125950865373
# Root Mean squared error: 0.29262819329082723
# 0.3928330585229879
# error:
# Mean absolute error: 0.2325644843608564
# Mean squared error: 0.08788716649386474
# Root Mean squared error: 0.2964576976465019
# 0.3954238825751635
# error:
# Mean absolute error: 0.2348706206995701
# Mean squared error: 0.08999347200804413
# Root Mean squared error: 0.29998911981610954
# 0.398302082881951
# error:
# Mean absolute error: 0.2372754570984445
# Mean squared error: 0.09130443921218294
# Root Mean squared error: 0.3021662443294799
# 0.3905795660037399
# error:
# Mean absolute error: 0.23356573893789268
# Mean squared error: 0.0873243481527694
# Root Mean squared error: 0.29550693418728674
# 0.38841738593040764
# error:
# Mean absolute error: 0.23825616112839174
# Mean squared error: 0.09234387037151445
# Root Mean squared error: 0.30388134258541516
# 0.3964487245427487
# error:
# Mean absolute error: 0.23444919452234744
# Mean squared error: 0.09034901193576962
# Root Mean squared error: 0.3005811237183227
# 0.3863629895782996
# error:
# Mean absolute error: 0.23437634009092967
# Mean squared error: 0.09000436098200065
# Root Mean squared error: 0.3000072682152895
# 0.39748068599715713
# error:
# Mean absolute error: 0.23479238065929217
# Mean squared error: 0.09020993391235405
# Root Mean squared error: 0.30034968605336354
# 0.3993434465554142
# error:
# Mean absolute error: 0.23564722854554648
# Mean squared error: 0.09119284784819497
# Root Mean squared error: 0.30198153560804836
# 0.40232449163612016
# error:
# Mean absolute error: 0.23641925806242295
# Mean squared error: 0.09087458107913561
# Root Mean squared error: 0.30145411106690123
# 0.38316745241107164
# error:
# Mean absolute error: 0.23549078343609228
# Mean squared error: 0.08971991353801666
# Root Mean squared error: 0.2995328254766356
# 0.379680070598023
# error:
# Mean absolute error: 0.2383379299151725
# Mean squared error: 0.09239658372778416
# Root Mean squared error: 0.30396806366423457
# 0.3799072813945057
# error:
# Mean absolute error: 0.23780286964777117
# Mean squared error: 0.09229826533933283
# Root Mean squared error: 0.3038062957532856
# 0.3916102099074953
# error:
# Mean absolute error: 0.2325918624859975
# Mean squared error: 0.08923232433525582
# Root Mean squared error: 0.29871780049949453
# 0.3777560990645591
# error:
# Mean absolute error: 0.23097514437917144
# Mean squared error: 0.08747914175706271
# Root Mean squared error: 0.29576873018806893
# 0.3903996566091652
# error:
# Mean absolute error: 0.2339058420991051
# Mean squared error: 0.0897875440539132
# Root Mean squared error: 0.2996456975394661
# 0.4020513242577529
# error:
# Mean absolute error: 0.23678301789005385
# Mean squared error: 0.0904203539329538
# Root Mean squared error: 0.30069977374942236
# 0.3824328120594842
# error:
# Mean absolute error: 0.23524378555168782
# Mean squared error: 0.090447265333054
# Root Mean squared error: 0.30074451837573696
# 0.3774933419829344
# error:
# Mean absolute error: 0.24371187576705278
# Mean squared error: 0.09590002911980629
# Root Mean squared error: 0.3096772983604163
# 0.3938687642411607
# error:
# Mean absolute error: 0.23620170200564852
# Mean squared error: 0.08998346989298114
# Root Mean squared error: 0.2999724485564985
# 0.40111332533848787
# error:
# Mean absolute error: 0.2359159514337654
# Mean squared error: 0.09023227063946243
# Root Mean squared error: 0.3003868682873178
# 0.3904646094098896
# error:
# Mean absolute error: 0.23483466244155035
# Mean squared error: 0.09052834563321419
# Root Mean squared error: 0.300879287477909
# 0.40335600721142106
# error:
# Mean absolute error: 0.22896507558562393
# Mean squared error: 0.08581143770995836
# Root Mean squared error: 0.29293589351589944
# 0.38412245616349305
# error:
# Mean absolute error: 0.23666739831556938
# Mean squared error: 0.09117429103816564
# Root Mean squared error: 0.3019508089708747
# 0.3952264020066242
# error:
# Mean absolute error: 0.23441417054704872
# Mean squared error: 0.08967240368654089
# Root Mean squared error: 0.2994535083891002
# 0.38403856043112217
# error:
# Mean absolute error: 0.23470973360909086
# Mean squared error: 0.08982967578761054
# Root Mean squared error: 0.2997159918783289
# 0.40215006589139013
# error:
# Mean absolute error: 0.23678057707104747
# Mean squared error: 0.09144494055312173
# Root Mean squared error: 0.30239864509141196
# 0.38103954112662364
# error:
# Mean absolute error: 0.23708818455076136
# Mean squared error: 0.0920560985625703
# Root Mean squared error: 0.3034074794110559
# 0.37243379111249253
# error:
# Mean absolute error: 0.2358126183351894
# Mean squared error: 0.09078150572545537
# Root Mean squared error: 0.30129969420073327
# 0.39460363595613923
# error:
# Mean absolute error: 0.23425014395043275
# Mean squared error: 0.09025904127481436
# Root Mean squared error: 0.3004314252451204
# 0.3848488638000933
# error:
# Mean absolute error: 0.23903316094038507
# Mean squared error: 0.09270130751982644
# Root Mean squared error: 0.304468894174473
# 0.37866259700309857
# error:
# Mean absolute error: 0.2338886151365914
# Mean squared error: 0.08995153173349198
# Root Mean squared error: 0.2999192086770902
# 0.3807621550108373
# error:
# Mean absolute error: 0.2334674198314243
# Mean squared error: 0.08973333570679394
# Root Mean squared error: 0.29955522981045407
# 0.3928065400396814
# error:
# Mean absolute error: 0.23468029651090128
# Mean squared error: 0.0901985645845536
# Root Mean squared error: 0.3003307586387941
# 0.39417218659754527
# error:
# Mean absolute error: 0.23031634460489225
# Mean squared error: 0.08779188582806752
# Root Mean squared error: 0.2962969554822788
# 0.39279555197263727
# error:
# Mean absolute error: 0.23193789611814764
# Mean squared error: 0.08785651229545612
# Root Mean squared error: 0.29640599234066795
# 0.40095071541105753
# error:
# Mean absolute error: 0.23470081723369599
# Mean squared error: 0.08913610550689058
# Root Mean squared error: 0.2985567040059402
# 0.37142220024938866
# error:
# Mean absolute error: 0.23537302363324192
# Mean squared error: 0.09121341247427796
# Root Mean squared error: 0.3020155831646406
# 0.3965909515951025
# error:
# Mean absolute error: 0.23613690279227587
# Mean squared error: 0.09069649045664205
# Root Mean squared error: 0.30115858024742054
# 0.3745506175112814
# error:
# Mean absolute error: 0.2361039068834103
# Mean squared error: 0.09221705555484835
# Root Mean squared error: 0.30367261245434757
# 0.3794779429536437
# error:
# Mean absolute error: 0.2366541494550569
# Mean squared error: 0.09000273631739139
# Root Mean squared error: 0.3000045604943221
# 0.3876375524127592
# error:
# Mean absolute error: 0.23455385302300968
# Mean squared error: 0.09094544406177157
# Root Mean squared error: 0.3015716234359121
# 0.39796045197076446
# error:
# Mean absolute error: 0.2379057547004687
# Mean squared error: 0.09294573091946859
# Root Mean squared error: 0.30487002299253463
# 0.40006614656765416
# error:
# Mean absolute error: 0.2348662710023975
# Mean squared error: 0.09130642725067609
# Root Mean squared error: 0.30216953395515583
# 0.3875943097742134
# error:
# Mean absolute error: 0.23889678569276843
# Mean squared error: 0.09278471737015247
# Root Mean squared error: 0.30460583935662244
# 0.39824930410820725
# error:
# Mean absolute error: 0.2394242948855553
# Mean squared error: 0.09326263746878757
# Root Mean squared error: 0.30538932114399087
# 0.3541831250290959
# error:
# Mean absolute error: 0.23921115781716337
# Mean squared error: 0.0930699417770221
# Root Mean squared error: 0.30507366614806675
# 0.3989790674812119
# error:
# Mean absolute error: 0.23335590235975817
# Mean squared error: 0.08881545184808806
# Root Mean squared error: 0.29801921389079605
# 0.3845759135692134
# error:
# Mean absolute error: 0.23446927457986355
# Mean squared error: 0.08998727322122146
# Root Mean squared error: 0.29997878795211746
# 0.39902931571317324
# error:
# Mean absolute error: 0.23339275662208583
# Mean squared error: 0.08815435698293243
# Root Mean squared error: 0.29690799413780095
# 0.4087113465255746
# error:
# Mean absolute error: 0.23284677024309045
# Mean squared error: 0.08904356968085483
# Root Mean squared error: 0.29840169181969267
# 0.3672530870453403
# error:
# Mean absolute error: 0.23771463387712327
# Mean squared error: 0.09317849667743462
# Root Mean squared error: 0.3052515301803328
# 0.39183696773726107
# error:
# Mean absolute error: 0.2373960779971348
# Mean squared error: 0.09110247037985575
# Root Mean squared error: 0.3018318577947923
# 0.3901691524437879
# error:
# Mean absolute error: 0.239476127121
# Mean squared error: 0.09363981590395518
# Root Mean squared error: 0.30600623507365854
# 0.3856452670402607
# error:
# Mean absolute error: 0.23759712557711352
# Mean squared error: 0.09296995964579696
# Root Mean squared error: 0.30490975656052227
# 0.40636062508713144
# error:
# Mean absolute error: 0.2332019400750214
# Mean squared error: 0.08837991769086062
# Root Mean squared error: 0.29728760097060997
# 0.39845597781218867
# error:
# Mean absolute error: 0.23904763687809552
# Mean squared error: 0.09262294037062135
# Root Mean squared error: 0.3043401721275411
# 0.41383314944967964
# error:
# Mean absolute error: 0.23012956876416527
# Mean squared error: 0.08659897856993212
# Root Mean squared error: 0.2942770439057932
# 0.406113917155827
# error:
# Mean absolute error: 0.23461589099491637
# Mean squared error: 0.08922832335531049
# Root Mean squared error: 0.29871110350187935
# 0.38541822411016646
# error:
# Mean absolute error: 0.2392463988565125
# Mean squared error: 0.09373125790204172
# Root Mean squared error: 0.30615561060029867
# 0.3910076925910638
# error:
# Mean absolute error: 0.23640781906980382
# Mean squared error: 0.09226166199640855
# Root Mean squared error: 0.30374604852805664
# Best accuracy is 0.41673569956049994 on Random_state 84

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=84)
lm=LinearRegression()
lm.fit(x_train,y_train)
predlm=lm.predict(x_test)
r2score=r2_score(y_test,predlm)
print(r2_score(y_test,predlm))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predlm))
mean_squared_error_lm=mean_squared_error(y_test,predlm)
print('Mean squared error:',mean_squared_error_lm)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.41673569956049994
# error:
# Mean absolute error: 0.2275283972706915
# Mean squared error: 0.08437414772584366
# Root Mean squared error: 0.44901436820828755

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
preddtr=dtr.predict(x_test)
r2score=r2_score(y_test,preddtr)
print(r2_score(y_test,preddtr))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,preddtr))
mean_squared_error_dtr=mean_squared_error(y_test,preddtr)
print('Mean squared error:',mean_squared_error_dtr)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,preddtr)))
# Out:
# 0.6455826322293723
# error:
# Mean absolute error: 0.1512796086508754
# Mean squared error: 0.05126949021627188
# Root Mean squared error: 0.2264276710481117

# %%
knn=KNeighborsRegressor(n_neighbors=5)
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
predknn=knn.predict(x_test)
r2score=r2_score(y_test,predknn)
print(r2_score(y_test,predknn))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predknn))
mean_squared_error_knn=mean_squared_error(y_test,predknn)
print('Mean squared error:',mean_squared_error_knn)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predknn)))
# Out:
# 0.817357079151344
# error:
# Mean absolute error: 0.11379351184346034
# Mean squared error: 0.026420853759011324
# Root Mean squared error: 0.16254492843214557

# %%
svm=SVR()
svm.fit(x_train,y_train)
predsvr=svm.predict(x_test)
r2score=r2_score(y_test,predsvr)
print(r2_score(y_test,predsvr))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predsvr))
mean_squared_error_svr=mean_squared_error(y_test,predsvr)
print('Mean squared error:',mean_squared_error_svr)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predsvr)))
# Out:
# 0.5152831130748456
# error:
# Mean absolute error: 0.1995734347633484
# Mean squared error: 0.07011842520074858
# Root Mean squared error: 0.26479883912273594

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
ls=Lasso(alpha=.0001)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred=ls.predict(x_test)
r2score=r2_score(y_test,pred)
print(r2_score(y_test,pred))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,pred))
mean_squared_error_ls=mean_squared_error(y_test,pred)
print('Mean squared error:',mean_squared_error_ls)
print('Mean squared error:',mean_squared_error(y_test,pred))
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# 0.4167205519667099
# error:
# Mean absolute error: 0.22753215570075735
# Mean squared error: 0.08437633895427162
# Mean squared error: 0.08437633895427162
# Root Mean squared error: 0.2904760557331217

# %%
rd=Ridge(alpha=.0001)
rd.fit(x_train,y_train)
rd.score(x_train,y_train)
predrd=rd.predict(x_test)
r2score=r2_score(y_test,predrd)
print(r2_score(y_test,predrd))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predrd))
mean_squared_error_rd=mean_squared_error(y_test,predrd)
print('Mean squared error:',mean_squared_error_rd)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predrd)))
# Out:
# 0.4167356994063951
# error:
# Mean absolute error: 0.22752839730811295
# Mean squared error: 0.08437414774813623
# Root Mean squared error: 0.2904722839586184

# %%
el=ElasticNet(alpha=.0001)
el.fit(x_train,y_train)
el.score(x_train,y_train)
predel=el.predict(x_test)
r2score=r2_score(y_test,predel)
print(r2_score(y_test,pred))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predel))
mean_squared_error_el=mean_squared_error(y_test,predel)
print('Mean squared error:',mean_squared_error_el)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predel)))
# Out:
# 0.4167205519667099
# error:
# Mean absolute error: 0.22753022552644
# Mean squared error: 0.08437537354183956
# Root Mean squared error: 0.2904743939520996

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
r2score=r2_score(y_test,predrf)
print(r2_score(y_test,predrf))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predrf))
mean_squared_error_rf=mean_squared_error(y_test,predrf)
print('Mean squared error:',mean_squared_error_rf)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# 0.8143628192049626
# error:
# Mean absolute error: 0.11630538105046344
# Mean squared error: 0.026853998957260553
# Root Mean squared error: 0.163871898009575

# %%
from sklearn.ensemble import AdaBoostRegressor
ad=AdaBoostRegressor()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
r2score=r2_score(y_test,predad)
print(r2_score(y_test,predad))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predad))
mean_squared_error_ad=mean_squared_error(y_test,predad)
print('Mean squared error:',mean_squared_error_ad)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predad)))
# Out:
# 0.4728863976116434
# error:
# Mean absolute error: 0.22028100874591555
# Mean squared error: 0.07625147111301736
# Root Mean squared error: 0.27613668918312423

# %% [markdown]
# K - Neighbors Regressor is the best algorithm.

# %% [markdown]
# ## **Cross Validation Score.**

# %%
from sklearn.model_selection import cross_val_score
knnscores=cross_val_score(knn,x,y,cv=5)
print(knnscores)
# Out:
# [-0.33782941  0.10868162  0.13577791 -0.08329639 -0.21264309]

# %%
# Fix the sign
scoresknn=(knnscores)**2

# %%
scoresknn
# Out:
# array([0.11412871, 0.01181169, 0.01843564, 0.00693829, 0.04521708])

# %%
print(scoresknn.mean(),scoresknn.std())
# Out:
# 0.039306283256445106 0.03968011163361294

# %%
list1=[0.817357079151344]
list2=[0.039306283256445106]
difference=[]
zip_object = zip(list1, list2)
for list1_i, list2_i in zip_object:
    difference.append(list1_i-list2_i)

# %%
print(difference)
# Out:
# [0.7780507958948989]

# %% [markdown]
# As the difference between accuracy scores and cross validation scores of K-neighbors Regressor is only 7%. So, It is verified that K-neighbors Regressor is the best algorithm for this model with accuracy of 81.735%.

# %% [markdown]
# ## **Hyper Parameter Tuning.**

# %%
knn=KNeighborsRegressor(n_neighbors=5,algorithm='auto',weights='uniform',leaf_size=30,p=1)
knn.fit(x_train,y_train)
predknn=knn.predict(x_test)
predknn=knn.predict(x_test)
r2score=r2_score(y_test,predknn)
print(r2_score(y_test,predknn))
print('error:')
print('Mean absolute error:',mean_absolute_error(y_test,predknn))
mean_squared_error_knn=mean_squared_error(y_test,predknn)
print('Mean squared error:',mean_squared_error_knn)
print('Root Mean squared error:',np.sqrt(mean_squared_error(y_test,predknn)))
# Out:
# 0.8205345043147054
# error:
# Mean absolute error: 0.11294284243048403
# Mean squared error: 0.02596121215242018
# Root Mean squared error: 0.16112483406483366

# %% [markdown]
# ## **Saving the model.**

# %%
import joblib

# %%
joblib.dump(knn,"knn_avocado.obj")
# Out:
# ['knn_avocado.obj']
